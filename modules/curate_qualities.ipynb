# %%
from rdflib import BNode, URIRef, Literal, Graph, Namespace
from rdflib.collection import Collection
from rdflib.util import guess_format
from rdflib.namespace import RDF, XSD, RDFS, OWL, SKOS, DCTERMS, NamespaceManager
from rdflib.plugins.sparql import prepareQuery
from datetime import datetime
from urllib.request import urlopen, pathname2url
from urllib.parse import urlparse, urljoin
from typing import Dict, List, Tuple
import logging
from re import sub
from dotenv import load_dotenv
load_dotenv()

from deep_translator import GoogleTranslator

from openai import AzureOpenAI


logger = logging.getLogger()
logger.setLevel(logging.INFO)

def path2url(path):
    return urljoin(
      'file:', pathname2url(os.path.abspath(path)))

dir=os.getcwd()
PMDCO = Namespace('https://w3id.org/pmd/co/')
bfo2020_url='http://purl.obolibrary.org/obo/bfo/2020/bfo.owl'
BFO = Namespace(bfo2020_url+"/")    
OBO = Namespace('http://purl.obolibrary.org/obo/')
PROV= Namespace('http://www.w3.org/ns/prov#')
IOFAV = Namespace('https://spec.industrialontologies.org/ontology/core/meta/AnnotationVocabulary/')
PATO = Namespace('http://purl.obolibrary.org/obo/pato/releases/2023-05-18/pato-full.owl')

editor="Thomas Hanke"

#filename="pmdco-qualities-no_pato.ttl"
filename="pmdco-qualities.ttl"

this_ontology_url=path2url(filename)
pato_source="pato-full.owl"
pato_url=path2url(pato_source)
iao_source="iao.rdf"
iao_url=path2url(iao_source)

imported_from=URIRef('http://purl.obolibrary.org/obo/IAO_0000412')

output_filename="curated_"+filename.rsplit('.',1)[0]+'.rdf'
output_format='application/rdf+xml'

def get_base_uri(g: Graph):
    base_namespace=None
    for ns_prefix, namespace in list(g.namespace_manager.namespaces()):
        if ns_prefix.strip() in ['base', ""]:
            base_namespace = namespace
    if base_namespace:
        logging.debug(
            "found the following base or empty prefix namespace {}".format(
                base_namespace
            )
        )
    return base_namespace

# Snake Chase - your_term
def snake_case(s):
  return '_'.join(
    sub('([A-Z][a-z]+)', r' \1',
    sub('([A-Z]+)', r' \1',
    s.replace('-', ' '))).split()).lower()

# Camel Chase - yourTerm
def lower_camel_case(s):
  #print(s)
  s = sub(r"(_|-)+", " ", s).title().replace(" ", "")
  return ''.join([s[0].lower(), s[1:]])

# Pascal Chase -  YourTerm
def upper_camel_case(s):
  #print(s)
  s = sub(r"(_|-)+", " ", s).title().replace(" ", "")
  return s

def strip_special_chars(s):
    #return sub('[^A-Za-z0-9]+', ' ', s)
    return sub('\W+',' ', s )


def parse_graph(url: str, graph: Graph=Graph(), format: str = "") -> Graph:
    """Parse a Graph from web url to rdflib graph object
    Args:
        url (AnyUrl): Url to an web ressource
        graph (Graph): Existing Rdflib Graph object to parse data to.
    Returns:
        Graph: Rdflib graph Object
    """
    logging.debug("parsing graph from {}".format(url))
    parsed_url = urlparse(url)
    META = Namespace(url + "/")
    if not format:
        format = guess_format(parsed_url.path)
    if parsed_url.scheme in ["https", "http"]:
        graph.parse(urlopen(parsed_url.geturl()).read(), format=format)
    elif parsed_url.scheme == "file":
        graph.parse(parsed_url.path, format=format)
    graph.bind("meta", META)
    return graph

def add_ontology_header(g):
    g.bind('owl',OWL)
    g.bind('bfo',BFO)
    g.bind('obo',OBO)
    g.bind('skos',SKOS)
    g.bind('dcterms',DCTERMS)
    g.bind('iof-av',IOFAV)
    g.bind('pmdco',PMDCO)
    g.bind('prov',PROV)
    return g

sub_classes = prepareQuery("SELECT ?entity WHERE {?entity rdfs:subClassOf* ?parent}")

all_labels = prepareQuery("SELECT ?entity ?label WHERE {?entity rdfs:label ?label}")

all_labels_definitions = prepareQuery("SELECT ?entity ?label ?definition WHERE { \
                                      # ?entity rdfs:label ?label; \
                                        skos:definition ?definition. \
                                      }")

def get_all_sub_classes(superclass: URIRef, ontology: Graph) -> List[URIRef]:
    """Gets all subclasses of a given class.

    Args:
        superclass (URIRef): Rdflib URIRef of the superclass

    Returns:
        List[URIRef]: List of all subclasses
    """
    # parse template and add mapping results
    results = list(
        ontology.query(
            sub_classes,
            initBindings={"parent": superclass},
            # initNs={'cco': CCO, 'mseo': MSEO},
        ),
    )
    # print(list(ontology[ : RDFS.subClassOf]))
    classes = [result[0] for result in results]
    logger.debug("Found following subclasses of {}: {}".format(superclass, classes))
    logger.debug("Found {} subclasses of {}".format(len(classes),superclass))
    return classes

def filter_entities(entity_list: List, filter_words: List, g: Graph)-> List:
    """
    """
    res=entity_list.copy()
    for entity in entity_list:
        label=str(g.value(entity,RDFS.label))
        if any(word in label.lower() for word in filter_words):
            logger.debug('found a entity {} with label {} to be filter out'.format(entity,label))
            # we dont want this term and all its subclasses
            to_remove=get_all_sub_classes(entity,g)
            #print([this for this in to_remove if this not in to_add])
            [res.remove(this) for this in to_remove if this in res]
    logger.info("filtered out {} entities because there labels contain one of the words {}".format(len(entity_list)-len(res),filter_words))
    return res

def import_entities(g: Graph, g_superclass: URIRef, from_graph: Graph, from_graph_superclass: URIRef, filters: List[str]=[])-> Graph:
    to_import_entities=get_all_sub_classes(from_graph_superclass,from_graph)
    #substract already imported ones
    imported_entities=list(g.objects(None,imported_from))
    to_add=[shape for shape in to_import_entities if shape not in imported_entities]
    #apply ilter on labels
    if filters:
        to_add=filter_entities(to_add,filters,from_graph)
    i=0
    for shape in to_add:
        label=None
        definition=None
        #skip shape class
        if str(shape)==str(from_graph_superclass):
            g.add((g_superclass,imported_from,from_graph_superclass))
            continue
        else:
            i+=1
            for s,p, o in from_graph.triples((shape,None,None)):
                #print(s,p,o)
                if p==RDFS.label:
                    label=str(o)
                if p==OBO.IAO_0000115:
                    definition=o
            if label:
                short_iri=upper_camel_case(strip_special_chars(label))
                iri=URIRef(PMDCO+short_iri)
                g.add((iri,RDF.type,OWL.Class))
                g.add((iri,imported_from,shape))
                g.add((iri,RDFS.label,Literal(label,lang='en')))
                if definition:
                    g.add((iri,SKOS.definition,definition))
                g.add((iri,OBO.IAO_0000117,Literal("PERSON: " + editor )))
    logging.info("added {} entities from entity {} as subclasses to {}".format(i,from_graph_superclass,g_superclass))
    return g

# copys subclass relations from equivalentClasses of Pato
def copy_subclass_relations(g: Graph):
    i=0
    for s,p, o in g.triples((None,imported_from,None)):
        if isinstance(o,URIRef):
            subclassof=list(pato.objects(o,RDFS.subClassOf))
            for item in subclassof:
                pmd_class = g.value(predicate=imported_from, object=item, any=False)
                if pmd_class:
                    #print(s,RDFS.subClassOf,pmd_class)
                    g.add((s,RDFS.subClassOf,pmd_class))
                    i+=1
    logging.info("added {} subclass relations from equivalent pato entities".format(i))
    return g

chatclient = AzureOpenAI(
    api_key=os.environ.get("AOAI_API_KEY"),
    # https://learn.microsoft.com/en-us/azure/ai-services/openai/reference#rest-api-versioning
    api_version=os.environ.get("AOAI_API_VERSION"),
    # https://learn.microsoft.com/en-us/azure/cognitive-services/openai/how-to/create-resource?pivots=web-portal#create-a-resource
    azure_endpoint= os.environ.get("AOAI_API_BASE",""),
)

def translate_label_completion(text: str, target_language: str="de", definition: str=""): 
    prompt=f"Translate the following label into {target_language}: {text}, stick to the number of words and sequence of word classes if possible.\n"
    if definition:
        prompt+=f"Use the following definition as help: {definition}\n"
    response = chatclient.completions.create( 
    model="TEXTDAVINCI3",
    prompt=prompt,
    max_tokens=60, 
    n=1, 
    stop=None, 
    temperature=0.7, ) 
    return strip_special_chars(response.choices[0].text.strip())

def translate_labels_gpt(g: Graph, language: str='de'):
    res=dict()
    labels_definitions=g.query(all_labels_definitions)    
    for thing, label, definition in labels_definitions:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
        res[thing]["definition"]=definition
    i=9
    for thing, fields in res.items():
        if not all(lang in fields.keys() for lang in ("en","de")):
            if fields.get('en',None):
                definition=fields.get('definition','')
                label_de=Literal(translate_label_completion(fields['en'],target_language=language,definition=definition),lang=language)
                logging.info('adding german label {} for entity {}'.format(label_de, thing))
                g.add((thing,RDFS.label,label_de))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("translated {} labels to [{}]".format(i,language))
    return g

def translate_labels_google(g: Graph, language: str='de'):
    translator=GoogleTranslator(source='auto', target=language)
    res=dict()
    labels=g.query(all_labels)    
    for thing, label in labels:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
    i=0
    for thing, labels in res.items():
        if not all(lang in labels.keys() for lang in ("en","de")):
            #entitys with only one label
            #print(thing,labels)
            #translate and add triple
            if labels.get('en',None):
                label_de=Literal(translator.translate(labels['en']),lang=language)
                logging.info('adding german label {} for entity {}'.format(label_de, thing))
                g.add((thing,RDFS.label,label_de))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("translated {} labels to [{}]".format(i,language))
    return g

def entitle_all_labels(g: Graph):
    res=dict()
    labels=g.query(all_labels)    
    for thing, label in labels:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
    i=0

    for thing, labels in res.items():
        for lang, label in labels.items():
            entitled_label=str(label).title()
            if not str(label)==entitled_label:
                logging.debug('replacing label [{}] with [{}] on {}'.format(str(label), entitled_label, thing))
                #remove old label
                g.remove((thing,RDFS.label,label))
                #add capitalized one
                g.add((thing,RDFS.label,Literal(entitled_label,lang=getattr(label,'language',""))))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("entiteled {} labels".format(i))
    return g


def copy_label_definitions_from_external_terms(source: Graph, target: Graph):
    all_entities=list(source.subjects(unique=True))
    all_entities.extend(source.predicates(unique=True))
    subjects_with_labels={thing: label for thing, label in source.query(all_labels)}.keys()
    subjects_without_labels=[subject for subject in all_entities if subject not in subjects_with_labels and isinstance(subject,URIRef)]
    logger.info("found the following subjects without rdfs:label: {}".format(subjects_without_labels))
    logger.info("graph has {} entities without rdfs:label".format(len(subjects_without_labels)))
    target_subjects_with_labels={thing: label for thing, label in target.query(all_labels)}.keys()
    found_in_target=[subject for subject in subjects_without_labels if subject in target_subjects_with_labels]
    logger.debug("found the following subjects in target:\n{}".format(found_in_target))
    i=0
    for subject in found_in_target:
        for label in target.objects(subject,RDFS.label):
            source.add((subject,RDFS.label,label))
            i+=1
    logger.info("added {} labels for {} subjects found in target".format(i,len(found_in_target)))
    return source

# %%
pato=parse_graph(pato_url)
iao=parse_graph(iao_url)

# %%
#filename="curated_pmdco-qualities.rdf"
#this_ontology_url=path2url(filename)

print(this_ontology_url)
onto=Graph()
onto=parse_graph(this_ontology_url,graph=onto)
onto=add_ontology_header(onto)
# adding rdfs:label for increased readability in editor
onto=copy_label_definitions_from_external_terms(onto,iao)

default_filter=['increased', 'decreased', 'normal']
pato_map=[
    (onto.value(predicate=RDFS.label,object=Literal("Color", lang="en")),OBO.PATO_0000014,default_filter),
    (onto.value(predicate=RDFS.label,object=Literal("Shape", lang="en")),OBO.PATO_0000052,default_filter),
    (onto.value(predicate=RDFS.label,object=Literal("Size", lang="en")),OBO.PATO_0000117,["uniform", 'increased', 'decreased', 'normal']),
    (onto.value(predicate=RDFS.label,object=Literal("Structure", lang="en")),OBO.PATO_0000141,['accumulation','acinar','apoptotic','autogenous', 'fibrinoid', 'neoplastic','with','attachment','complete','water','increased', 'decreased', 'normal', 'maximal', 'from', 'to']),
    (onto.value(predicate=RDFS.label,object=Literal("Texture", lang="en")),OBO.PATO_0000150,default_filter),
    (onto.value(predicate=RDFS.label,object=Literal("Spatial Pattern", lang="en")),OBO.PATO_0000060,default_filter),
    #(onto.value(predicate=RDFS.label,object=Literal("Molecular Quality", lang="en")),OBO.PATO_0002182,["affinity", "concentration", "osmolality"," osmolarity"]),
    (onto.value(predicate=RDFS.label,object=Literal("Odor", lang="en")),OBO.PATO_0000058,default_filter),
    (onto.value(predicate=RDFS.label,object=Literal("Organismal Quality", lang="en")),OBO.PATO_0001995,["resistance", "response", "sensitivity", 'increased', 'decreased', 'normal']),
    (onto.value(predicate=RDFS.label,object=Literal("Cellular Quality", lang="en")),OBO.PATO_0001396,default_filter),
    ]
for target, source, filters in pato_map:
    if target and source:
        onto=import_entities(g=onto,g_superclass=target,from_graph=pato,from_graph_superclass=source,filters=filters)


onto=copy_subclass_relations(onto)
#onto=translate_labels_google(onto,language='de')
onto=translate_labels_gpt(onto,language='de')

onto=entitle_all_labels(onto)

onto.serialize(output_filename,format=output_format)
# Out:
# file:///C:/Users/hanke/projects/core-ontology/modules/pmdco-qualities.ttl
# INFO:root:found the following subjects without rdfs:label: [rdflib.term.URIRef('https://w3id.org/pmd/co'), rdflib.term.URIRef('https://w3id.org/pmd/co/relatesTo'), rdflib.term.URIRef('http://www.w3.org/ns/prov#editorialNote'), rdflib.term.URIRef('https://w3id.org/pmd/co/fromValue'), rdflib.term.URIRef('https://w3id.org/pmd/co/toValue'), rdflib.term.URIRef('https://w3id.org/pmd/co/characteristicOf'), rdflib.term.URIRef('http://purl.org/dc/terms/bibliographicCitation'), rdflib.term.URIRef('http://www.w3.org/ns/prov#constraints'), rdflib.term.URIRef('http://purl.org/dc/terms/created'), rdflib.term.URIRef('https://w3id.org/pmd/co/symbol'), rdflib.term.URIRef('http://purl.org/dc/terms/title'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#prefLabel'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#altLabel'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#someValuesFrom'), rdflib.term.URIRef('http://purl.org/dc/terms/created'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#imports'), rdflib.term.URIRef('https://w3id.org/pmd/co/symbol'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionIRI'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionInfo'), rdflib.term.URIRef('http://purl.org/dc/terms/title')]
# INFO:root:graph has 28 entities without rdfs:label
# INFO:root:added 0 labels for 0 subjects found in target
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000014 as subclasses to https://w3id.org/pmd/co/Color
# INFO:root:filtered out 8 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000052 as subclasses to https://w3id.org/pmd/co/Shape
# INFO:root:filtered out 47 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 21 entities from entity http://purl.obolibrary.org/obo/PATO_0000117 as subclasses to https://w3id.org/pmd/co/Size
# INFO:root:filtered out 56 entities because there labels contain one of the words ['accumulation', 'acinar', 'apoptotic', 'autogenous', 'neoplastic', 'with', 'attachment', 'complete', 'water', 'increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000141 as subclasses to https://w3id.org/pmd/co/Structure
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000150 as subclasses to https://w3id.org/pmd/co/Texture
# INFO:root:filtered out 3 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000060 as subclasses to https://w3id.org/pmd/co/SpatialPattern
# INFO:root:filtered out 3 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0000058 as subclasses to https://w3id.org/pmd/co/Odor
# INFO:root:filtered out 70 entities because there labels contain one of the words ['resistance', 'response', 'sensitivity', 'increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0001995 as subclasses to https://w3id.org/pmd/co/OrganismalQuality
# INFO:root:filtered out 3 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity http://purl.obolibrary.org/obo/PATO_0001396 as subclasses to https://w3id.org/pmd/co/CellularQuality
# INFO:root:added 848 subclass relations from equivalent pato entities
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Mating Typ Hefe  for entity https://w3id.org/pmd/co/AMatingTypeYeast
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label  for entity https://w3id.org/pmd/co/Abrased
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label  for entity https://w3id.org/pmd/co/AbsenceDueToDegeneration
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Akinusz wie ein vielblättriges Beerenobst wie z B Himbeere  for entity https://w3id.org/pmd/co/Acinus
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Actinodrom dreigeteilte Eigenschaft des Trägers durch das Haben von drei oder mehr primären Ästen die sich von einem einzigen Punkt ausstrahlen  for entity https://w3id.org/pmd/co/Actinodromous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Actinomorphe  for entity https://w3id.org/pmd/co/Actinomorphic
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Akuminiert for entity https://w3id.org/pmd/co/Acuminate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Adoleszent for entity https://w3id.org/pmd/co/Adolescent
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Aggregiert for entity https://w3id.org/pmd/co/Aggregated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Flügelform for entity https://w3id.org/pmd/co/Aliform
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Lebendig for entity https://w3id.org/pmd/co/Alive
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Allopolyploidie Chromosomen aus verschiedenen Arten  for entity https://w3id.org/pmd/co/Allopolyploidy
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Flachrandig bleiben Sie beim Anzahl der Wörter und der Reihenfolge der Wortklassen wenn möglich  for entity https://w3id.org/pmd/co/Alobate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Alpha Paarungstyp Hefe  for entity https://w3id.org/pmd/co/AlphaMatingTypeYeast
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Alternative Anordnung for entity https://w3id.org/pmd/co/AlternatePlacement
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ambidextre Handhabung keine Dominanz in Rechts oder Linkshändigkeit  for entity https://w3id.org/pmd/co/AmbidextrousHandedness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Amylose Zusammensetzung for entity https://w3id.org/pmd/co/AmyloseComposition
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Anker förmig for entity https://w3id.org/pmd/co/AnchorShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Anecic Organisatorische Eigenschaft die dem Träger dank seiner Fähigkeit mehr als 20 cm tief in den Boden zu graben und permanente vertikale Gänge zu mac for entity https://w3id.org/pmd/co/Anecic
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Aneuploidie die Anzahl und Reihenfolge der Wortarten beibehalten wenn möglich  for entity https://w3id.org/pmd/co/Aneuploid
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Form mit Winkel  for entity https://w3id.org/pmd/co/Angular
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Nach vorne gedreht  for entity https://w3id.org/pmd/co/AnteriorlyRotated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Antero posterior Flachgeformt for entity https://w3id.org/pmd/co/AnteroPosteriorlyFlattened
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Anteromedial Rotiert for entity https://w3id.org/pmd/co/AnteromediallyRotated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Antevertiert for entity https://w3id.org/pmd/co/Anteverted
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Antrorse Vorwärts oder nach oben gebogen  for entity https://w3id.org/pmd/co/Antrorse
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Anukleat for entity https://w3id.org/pmd/co/Anucleate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Amboss halte Dich an die Anzahl der Wörter und die Reihenfolge der Wortarten sofern möglich  for entity https://w3id.org/pmd/co/Anvil
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Arachnose feine verwobene Haare gebend die Erscheinung eines Spinnennetzes  for entity https://w3id.org/pmd/co/Arachnose
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Baumlebend morphologisch und physiologisch angepasst  for entity https://w3id.org/pmd/co/Arboreal
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogen for entity https://w3id.org/pmd/co/Arched
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Areolat  for entity https://w3id.org/pmd/co/Areolate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Pfeilförmig for entity https://w3id.org/pmd/co/ArrowShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Asymmetrisch for entity https://w3id.org/pmd/co/Asymmetrical
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Asymmetrisch Gekrümmt for entity https://w3id.org/pmd/co/AsymmetricallyCurved
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Abschwächen halte dich an die Anzahl der Wörter und die Reihenfolge der Wortklassen sofern möglich  for entity https://w3id.org/pmd/co/Attenuate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ohrähnlich  for entity https://w3id.org/pmd/co/Auriculate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Autopolyploidie  for entity https://w3id.org/pmd/co/Autopolyploid
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Auxotroph for entity https://w3id.org/pmd/co/Auxotrophic
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Abneigung for entity https://w3id.org/pmd/co/Aversion
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Frakturierung durch Avulsion  for entity https://w3id.org/pmd/co/AvulsionFractured
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bakterielle Paarungsart for entity https://w3id.org/pmd/co/BacterialMatingType
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Körperliche Ausgeglichenheit for entity https://w3id.org/pmd/co/Balance
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ausgeglichenheit for entity https://w3id.org/pmd/co/Balanced
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bandförmig for entity https://w3id.org/pmd/co/BandShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bändermuster  for entity https://w3id.org/pmd/co/Banded
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Empfindlicher Knall for entity https://w3id.org/pmd/co/BangSensitive
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebändert for entity https://w3id.org/pmd/co/Barred
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verhaltensqualität for entity https://w3id.org/pmd/co/BehavioralQuality
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verhaltensaktiv for entity https://w3id.org/pmd/co/BehaviouralActive
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verhaltensaktivität for entity https://w3id.org/pmd/co/BehaviouralActivity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verhaltensinaktiv for entity https://w3id.org/pmd/co/BehaviouralInactive
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Beige sehr blass gelbliches Braun  for entity https://w3id.org/pmd/co/Beige
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogen for entity https://w3id.org/pmd/co/Bent
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bikonkav  for entity https://w3id.org/pmd/co/Biconcave
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweikonvex for entity https://w3id.org/pmd/co/Biconvex
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweihörnig  for entity https://w3id.org/pmd/co/Bicornuate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweigeteilt  for entity https://w3id.org/pmd/co/Bifurcated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bilaterale Symmetrie for entity https://w3id.org/pmd/co/BilateralSymmetry
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweilappig for entity https://w3id.org/pmd/co/Bilobed
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweinukleatig for entity https://w3id.org/pmd/co/Binucleate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Biologische Qualität for entity https://w3id.org/pmd/co/BiologicalQuality
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Biologisches Geschlecht for entity https://w3id.org/pmd/co/BiologicalSex
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Biomaterial Reinheit for entity https://w3id.org/pmd/co/BiomaterialPurity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweigeteilt halten Sie sich an die Anzahl der Wörter und die Reihenfolge der Wortklassen wenn möglich  for entity https://w3id.org/pmd/co/Bipartite
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweizahnigkeit  for entity https://w3id.org/pmd/co/Biscupidate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Schwarz for entity https://w3id.org/pmd/co/Black
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label  Schwertartig  for entity https://w3id.org/pmd/co/BladeLike
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Blasierte Flüssigkeit unter der Oberfläche akkumuliert  for entity https://w3id.org/pmd/co/Blistered
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Fleckig  for entity https://w3id.org/pmd/co/Blotchy
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Blau Wellenlänge im sichtbaren Spektrum zwischen Grün und Indigo evoziert durch Strahlung mit Wellenlängen von ca 420 bis 490 Nanometer  for entity https://w3id.org/pmd/co/Blue
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Runde Form for entity https://w3id.org/pmd/co/Blunt
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label boomerangförmig for entity https://w3id.org/pmd/co/BoomerangShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Botryoidal Oberflächenform ähnlich Traubenmassen  for entity https://w3id.org/pmd/co/Botryoidal
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Schüssel förmig for entity https://w3id.org/pmd/co/BowlShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kurzkronig  for entity https://w3id.org/pmd/co/Brachydont
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verzweigt  for entity https://w3id.org/pmd/co/Branched
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zweigigkeit for entity https://w3id.org/pmd/co/Branchiness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Spröde bleiben Sie bei der Anzahl der Wörter und der Reihenfolge der Wortklassen wenn möglich  for entity https://w3id.org/pmd/co/Brittle
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Breit for entity https://w3id.org/pmd/co/Broad
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Brochidodromisch for entity https://w3id.org/pmd/co/Brochidodromous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zerbrochen  for entity https://w3id.org/pmd/co/Broken
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label In Zwei Teile Zerbrochen for entity https://w3id.org/pmd/co/BrokenIntoTwoPieces
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bronze metallisch glänzend medium braun  for entity https://w3id.org/pmd/co/Bronze
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Brutqualität for entity https://w3id.org/pmd/co/BroodQuality
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Brutgröße for entity https://w3id.org/pmd/co/BroodSize
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Überlebensfähigkeit des Nachwuchses for entity https://w3id.org/pmd/co/BroodViability
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Braun dunkelorange rot sehr schwach  for entity https://w3id.org/pmd/co/Brown
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Braun Grün for entity https://w3id.org/pmd/co/BrownGreen
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Bürstenartige Form for entity https://w3id.org/pmd/co/BrushLikeShape
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konvex Tränenform for entity https://w3id.org/pmd/co/Bulbous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kugelförmig for entity https://w3id.org/pmd/co/BulletShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label C förmig for entity https://w3id.org/pmd/co/CShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verkalkt for entity https://w3id.org/pmd/co/Calcified
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Porös Knochen  for entity https://w3id.org/pmd/co/Cancellous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kanähnlich for entity https://w3id.org/pmd/co/CaneLike
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Karpelenähnlich for entity https://w3id.org/pmd/co/CarpelLike
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Knorpelig im Besitz von Knorpelmengen  for entity https://w3id.org/pmd/co/Cartilaginous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Käsig for entity https://w3id.org/pmd/co/Caseous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kastrierter männlich  for entity https://w3id.org/pmd/co/CastratedMale
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Struktur Hohlräume for entity https://w3id.org/pmd/co/Cavities
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zelluläre Adhäsivität for entity https://w3id.org/pmd/co/CellularAdhesivity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zelluläre Motilität for entity https://w3id.org/pmd/co/CellularMotility
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zelluläre Potenz for entity https://w3id.org/pmd/co/CellularPotency
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zelluläre Qualität for entity https://w3id.org/pmd/co/CellularQuality
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zellularität for entity https://w3id.org/pmd/co/Cellularity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Chemische Relationale Qualität for entity https://w3id.org/pmd/co/ChemicalRelationalQuantity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Cicatrix artig  for entity https://w3id.org/pmd/co/Cicatricial
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zilienigkeit for entity https://w3id.org/pmd/co/Ciliatedness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Umrollen an der Oberfläche des Trägers spiralförmig abwärts gerollt  for entity https://w3id.org/pmd/co/Circinate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kreisen for entity https://w3id.org/pmd/co/Circling
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Rund for entity https://w3id.org/pmd/co/Circular
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gefiederte  for entity https://w3id.org/pmd/co/Cladodromous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konkav allmählich verdickend zum Ende hin  for entity https://w3id.org/pmd/co/Clavate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kluft  for entity https://w3id.org/pmd/co/Cleft
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Beschichtung for entity https://w3id.org/pmd/co/Coating
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gewunden for entity https://w3id.org/pmd/co/Coiled
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Wickeln for entity https://w3id.org/pmd/co/Coiling
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kollagenhaltig for entity https://w3id.org/pmd/co/Collagenous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zusammengebrochen for entity https://w3id.org/pmd/co/Collapsed
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Farbmuster for entity https://w3id.org/pmd/co/ColorPattern
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Farbig  for entity https://w3id.org/pmd/co/Colored
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Farblos for entity https://w3id.org/pmd/co/Colorless
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Säulenförmig for entity https://w3id.org/pmd/co/Columnar
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kompatibilität for entity https://w3id.org/pmd/co/Compatibility
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kompatibel for entity https://w3id.org/pmd/co/Compatible
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Komplexheit for entity https://w3id.org/pmd/co/Complex
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Komplexität anhaftend an einen Träger durch die Intrikatheit und Zusammensetzung des Trägers  for entity https://w3id.org/pmd/co/Complexity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zusammensetzung for entity https://w3id.org/pmd/co/Composition
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Komprimiert Gebrochen for entity https://w3id.org/pmd/co/CompressionFractured
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konkav  for entity https://w3id.org/pmd/co/Concave
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konkaves 3 D Form for entity https://w3id.org/pmd/co/Concave3DShape
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konkavität for entity https://w3id.org/pmd/co/Concavity
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konkav konvex for entity https://w3id.org/pmd/co/ConcavoConvex
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verdichtet for entity https://w3id.org/pmd/co/Condensed
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verstopft  for entity https://w3id.org/pmd/co/Congested
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konisch  for entity https://w3id.org/pmd/co/Conical
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label  for entity https://w3id.org/pmd/co/Constricted
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Verunreinigung for entity https://w3id.org/pmd/co/Contamination
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konvex for entity https://w3id.org/pmd/co/Convex
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konvexe 3 D Form for entity https://w3id.org/pmd/co/Convex3DShape
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gewunden an der Anzahl der Wörter und der Reihenfolge der Wortklassen festhalten wenn möglich  for entity https://w3id.org/pmd/co/Convolute
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Koordiniert an die Anzahl der Wörter und die Reihenfolge der Wortarten halten falls möglich  for entity https://w3id.org/pmd/co/Coordinated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Koordination bewahren Sie die Anzahl der Wörter und die Abfolge der Wortklassen bei wenn möglich  for entity https://w3id.org/pmd/co/Coordination
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Corymb artig halten Sie sich an die Anzahl der Wörter und die Reihenfolge der Wortarten wenn möglich  for entity https://w3id.org/pmd/co/CorymbLike
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kraspedodromus for entity https://w3id.org/pmd/co/Craspedodromous
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label kreisförmig abgerundet for entity https://w3id.org/pmd/co/CrescentShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Siebähnlich  for entity https://w3id.org/pmd/co/Cribriform
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Krönend ähnlich for entity https://w3id.org/pmd/co/CrownLike
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kuboid for entity https://w3id.org/pmd/co/Cuboid
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Keilförmig am Apex breiter und an der Basis schmaler  for entity https://w3id.org/pmd/co/Cuneate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Kelchförmig for entity https://w3id.org/pmd/co/CupShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Cupulierte Qualität for entity https://w3id.org/pmd/co/Cupulate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gewellt for entity https://w3id.org/pmd/co/Curled
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Cursorial for entity https://w3id.org/pmd/co/Cursorial
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Krümmung for entity https://w3id.org/pmd/co/Curvature
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogen for entity https://w3id.org/pmd/co/Curved
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gekrümmter Schwanz for entity https://w3id.org/pmd/co/CurvedCaudal
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gekrümmter Rücken  for entity https://w3id.org/pmd/co/CurvedDorsal
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogene Seite for entity https://w3id.org/pmd/co/CurvedLateral
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogen Linguallig  for entity https://w3id.org/pmd/co/CurvedLingually
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gekrümmt Mittelteil for entity https://w3id.org/pmd/co/CurvedMedial
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogene Rostrale for entity https://w3id.org/pmd/co/CurvedRostral
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gebogene Ventral  for entity https://w3id.org/pmd/co/CurvedVentral
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Spitz zulaufend for entity https://w3id.org/pmd/co/Cuspidate
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Formeigenschaft die infolge tiefer Einschnitte beim Träger vorliegt  for entity https://w3id.org/pmd/co/Cut
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Cyan eine Farbe bestehend aus Grün und Blautönen  for entity https://w3id.org/pmd/co/Cyan
# ...
# INFO:root:adding german label Unverziert for entity https://w3id.org/pmd/co/Unornamented
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Unpigmentiert for entity https://w3id.org/pmd/co/Unpigmented
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ungezähnt halte an der Zahl der Wörter und der Reihenfolge der Wortklassen fest sofern möglich  for entity https://w3id.org/pmd/co/Unserrated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Unstratifiziert for entity https://w3id.org/pmd/co/Unstratified
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Unstrukturiert for entity https://w3id.org/pmd/co/Unstructured
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Nach oben gebogen for entity https://w3id.org/pmd/co/Upturned
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label V förmig for entity https://w3id.org/pmd/co/VShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label vakuolisiert for entity https://w3id.org/pmd/co/Vacuolated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Variable Farbe for entity https://w3id.org/pmd/co/VariableColor
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ventral Rotiert  for entity https://w3id.org/pmd/co/VentrallyRotated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Vermilion eine Farbe aus rotem und orangem Farbton mit einer leichten Graufärbung  for entity https://w3id.org/pmd/co/Vermilion
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Vertikal for entity https://w3id.org/pmd/co/Vertical
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Angehöriger Reststruktur der Entwicklung Evolution  for entity https://w3id.org/pmd/co/Vestigial
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Lebensfähigkeit for entity https://w3id.org/pmd/co/Viability
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Überlebensfähig halte die Anzahl der Wörter und die Wortklassenfolge bei wenn möglich  for entity https://w3id.org/pmd/co/Viable
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Villiforme for entity https://w3id.org/pmd/co/Villiform
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Violett for entity https://w3id.org/pmd/co/Violet
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Virulenz for entity https://w3id.org/pmd/co/Virulence
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Klebrig for entity https://w3id.org/pmd/co/Viscid
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label W förmig for entity https://w3id.org/pmd/co/WShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Tailliert  for entity https://w3id.org/pmd/co/Waisted
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Wartig rauhe Oberfläche  for entity https://w3id.org/pmd/co/Warty
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Weichheit durch langkettige Aliphaten Lipide  for entity https://w3id.org/pmd/co/Waxiness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Wachsartig langkettige Aliphatische Lipide an der Oberfläche eines Organismus  for entity https://w3id.org/pmd/co/Waxy
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gut Differenziert for entity https://w3id.org/pmd/co/WellDifferentiated
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Weiß for entity https://w3id.org/pmd/co/White
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gesamtheit for entity https://w3id.org/pmd/co/Whole
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ganzheit halte die Anzahl der Wörter und die Reihenfolge der Wortklassen bei wenn möglich  for entity https://w3id.org/pmd/co/Wholeness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Umgreift bleib bei der Anzahl der Wörter und der Reihenfolge der Wortarten sofern möglich  for entity https://w3id.org/pmd/co/Whorled
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Welkend for entity https://w3id.org/pmd/co/Wilty
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Faltengesichtig haften an der Anzahl der Wörter und Sequenz der Wortklassen wenn möglich  for entity https://w3id.org/pmd/co/Wrinkled
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label X förmig for entity https://w3id.org/pmd/co/XShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Y förmig for entity https://w3id.org/pmd/co/YShaped
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Hefe Mating Typ for entity https://w3id.org/pmd/co/YeastMatingType
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gelb for entity https://w3id.org/pmd/co/Yellow
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gelb Braun for entity https://w3id.org/pmd/co/YellowBrown
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gelb Grün for entity https://w3id.org/pmd/co/YellowGreen
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Gelb Orange for entity https://w3id.org/pmd/co/YellowOrange
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Zygomorphisch  for entity https://w3id.org/pmd/co/Zygomorphic
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Hohes Nukleär Zytoplasmatisches Verhältnis for entity https://w3id.org/pmd/co/HighNuclear/CytoplasmicRatio
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Nukleär Zytoplasmatischer Verhältnis for entity https://w3id.org/pmd/co/Nuclear/CytoplasmicRatio
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label 1 D Ausdehnung for entity https://w3id.org/pmd/co/1DExtent
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Höhe for entity https://w3id.org/pmd/co/Height
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Länge for entity https://w3id.org/pmd/co/Length
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Radius for entity https://w3id.org/pmd/co/Radius
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Dicke for entity https://w3id.org/pmd/co/Thickness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Ungleichmäßige Dicke for entity https://w3id.org/pmd/co/IrregularThickness
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Breite for entity https://w3id.org/pmd/co/Width
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Durchmesser for entity https://w3id.org/pmd/co/Diameter
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Antero posteraler Durchmesser for entity https://w3id.org/pmd/co/AnteriorPosteriorDiameter
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Konstanter Durchmesser for entity https://w3id.org/pmd/co/UniformDiameter
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Tiefe for entity https://w3id.org/pmd/co/Depth
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Umfang for entity https://w3id.org/pmd/co/Perimeter
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Umfang for entity https://w3id.org/pmd/co/Circumference
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label 2 D Ausmaß for entity https://w3id.org/pmd/co/2DExtent
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label 2 D Bereichsqualität for entity https://w3id.org/pmd/co/Area
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label 3 D Ausdehnung for entity https://w3id.org/pmd/co/3DExtent
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Volumen for entity https://w3id.org/pmd/co/Volume
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Volumeneigenschaft einer Substanzmasse anhand des dreidimensionalen Raums den sie einnimmt  for entity https://w3id.org/pmd/co/SpecificVolume
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Molares Volumen for entity https://w3id.org/pmd/co/MolarVolume
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Dendritische Feldgröße for entity https://w3id.org/pmd/co/DendriticFieldSize
# INFO:httpx:HTTP Request: POST https://iwm-sit.openai.azure.com//openai/deployments/TEXTDAVINCI3/completions?api-version=2023-03-15-preview "HTTP/1.1 200 OK"
# INFO:root:adding german label Abgeschrägte Größe for entity https://w3id.org/pmd/co/TaperedSize
# INFO:root:translated 856 labels to [de]
# INFO:root:entiteled 282 labels
# <Graph identifier=N09e8d33676c54964a908ca7d085fc900 (<class 'rdflib.graph.Graph'>)>
