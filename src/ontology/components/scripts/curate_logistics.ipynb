# %%
from rdflib import BNode, URIRef, Literal, Graph, Namespace
from rdflib.collection import Collection
from rdflib.util import guess_format
from rdflib.namespace import RDF, XSD, RDFS, OWL, SKOS, DCTERMS, NamespaceManager
from rdflib.plugins.sparql import prepareQuery
from datetime import datetime
from urllib.request import urlopen, pathname2url
from urllib.parse import urlparse, urljoin
from typing import Dict, List, Tuple
from pathlib import Path
import logging
from re import sub
import os
from dotenv import load_dotenv
import pyhornedowl
load_dotenv()

from deep_translator import GoogleTranslator

from openai import AzureOpenAI


logger = logging.getLogger()
logger.setLevel(logging.INFO)


dir=os.getcwd()
PMDCO = Namespace('https://w3id.org/pmd/co/')
bfo2020_url='http://purl.obolibrary.org/obo/bfo/2020/bfo.owl'
BFO = Namespace(bfo2020_url+"/")    
OBO = Namespace('http://purl.obolibrary.org/obo/')
PROV= Namespace('http://www.w3.org/ns/prov#')
IOFAV = Namespace('https://spec.industrialontologies.org/ontology/core/meta/AnnotationVocabulary/')
IOFCORE = Namespace('https://spec.industrialontologies.org/ontology/core/Core/')
IOFSUPPLY = Namespace('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/')

#PATO = Namespace('http://purl.obolibrary.org/obo/pato/releases/2023-05-18/pato-full.owl')

#editor="Thomas Hanke"

#filename="pmdco-qualities-no_pato.ttl"
filename="../pmdco-logistics.owl"

this_ontology_path=Path(filename).absolute()
#pato_source="pato-full.owl"
iof_supplychain_url="https://raw.githubusercontent.com/iofoundry/ontology/refs/heads/master/supplychain/SupplyChain.rdf"
iao_url="https://raw.githubusercontent.com/information-artifact-ontology/IAO/refs/heads/master/iao.owl"
imported_from=URIRef('http://purl.obolibrary.org/obo/IAO_0000412')

output_filename="curated_"+filename.rsplit('.',1)[0]+'.rdf'
output_format='application/rdf+xml'

def get_base_uri(g: Graph):
    base_namespace=None
    for ns_prefix, namespace in list(g.namespace_manager.namespaces()):
        if ns_prefix.strip() in ['base', ""]:
            base_namespace = namespace
    if base_namespace:
        logging.debug(
            "found the following base or empty prefix namespace {}".format(
                base_namespace
            )
        )
    return base_namespace

# Snake Chase - your_term
def snake_case(s):
  return '_'.join(
    sub('([A-Z][a-z]+)', r' \1',
    sub('([A-Z]+)', r' \1',
    s.replace('-', ' '))).split()).lower()

# Camel Chase - yourTerm
def lower_camel_case(s):
  #print(s)
  s = sub(r"(_|-)+", " ", s).title().replace(" ", "")
  return ''.join([s[0].lower(), s[1:]])

# Pascal Chase -  YourTerm
def upper_camel_case(s):
  #print(s)
  s = sub(r"(_|-)+", " ", s).title().replace(" ", "")
  return s

def strip_special_chars(s):
    #return sub('[^A-Za-z0-9]+', ' ', s)
    return sub(r'\W+',' ', s )


def parse_graph(path: Path, graph: Graph=Graph()) -> Graph:
    """Parse a Graph from web url to rdflib graph object
    Args:
        url (AnyUrl): Url to an web ressource
        graph (Graph): Existing Rdflib Graph object to parse data to.
    Returns:
        Graph: Rdflib graph Object
    """
    #logging.debug("parsing graph from {}".format(url))
    #parsed_url = urlparse(url)
    #META = Namespace(url + "/")
    #if not format:
    #    format = guess_format(parsed_url.path)
    #format="rdf/xml"
    #print(format)
    ontology = pyhornedowl.open_ontology(path.as_posix(),serialization='ofn')
    turtle_name = path.name.replace('.owl', '.xml')
    turtle_path = Path(f"./{turtle_name}")
    ontology.save_to_file(turtle_name, serialization='owl')
    turtle_path = Path(f"./{turtle_name}")
    graph.parse(turtle_path.as_posix(), format='xml')
    # graph.bind("meta", META)
    return graph

def add_ontology_header(g):
    g.bind('owl',OWL)
    g.bind('bfo',BFO)
    g.bind('obo',OBO)
    g.bind('skos',SKOS)
    g.bind('dcterms',DCTERMS)
    g.bind('iof-av',IOFAV)
    g.bind('pmdco',PMDCO)
    g.bind('prov',PROV)
    return g

sub_classes = prepareQuery("SELECT ?entity WHERE {?entity rdfs:subClassOf* ?parent}")

all_labels = prepareQuery("SELECT ?entity ?label WHERE {?entity rdfs:label ?label}")

all_labels_definitions = prepareQuery("SELECT ?entity ?label ?definition WHERE { \
                                      # ?entity rdfs:label ?label; \
                                        skos:definition ?definition. \
                                      }")

def get_all_sub_classes(superclass: URIRef, ontology: Graph) -> List[URIRef]:
    """Gets all subclasses of a given class.

    Args:
        superclass (URIRef): Rdflib URIRef of the superclass

    Returns:
        List[URIRef]: List of all subclasses
    """
    # parse template and add mapping results
    results = list(
        ontology.query(
            sub_classes,
            initBindings={"parent": superclass}
            # initNs={'cco': CCO, 'mseo': MSEO},
        ),
    )
    # print(list(ontology[ : RDFS.subClassOf]))
    classes = [result[0] for result in results]
    print("Found following subclasses of {}: {}".format(superclass, classes))
    print("Found {} subclasses of {}".format(len(classes),superclass))
    return classes

def filter_entities(entity_list: List, filter_words: List, g: Graph)-> List:
    """
    """
    res=entity_list.copy()
    for entity in entity_list:
        label=str(g.value(entity,RDFS.label))
        if any(word in label.lower() for word in filter_words):
            logger.debug('found a entity {} with label {} to be filter out'.format(entity,label))
            # we dont want this term and all its subclasses
            to_remove=get_all_sub_classes(entity,g)
            #print([this for this in to_remove if this not in to_add])
            [res.remove(this) for this in to_remove if this in res]
    logger.info("filtered out {} entities because there labels contain one of the words {}".format(len(entity_list)-len(res),filter_words))
    return res

def import_entities(g: Graph, g_superclass: URIRef, from_graph: Graph, from_graph_superclass: URIRef, filters: List[str]=[])-> Graph:
    print("importing entities from {} as subclasses of {}".format(from_graph_superclass,g_superclass))
    to_import_entities=get_all_sub_classes(from_graph_superclass,from_graph)
    #substract already imported ones
    imported_entities=list(g.objects(None,imported_from))
    print(to_import_entities)
    to_add=[concept for concept in to_import_entities if concept not in imported_entities]
    #apply ilter on labels
    if filters:
        to_add=filter_entities(to_add,filters,from_graph)
    i=0
    for concept in to_add:
        print(concept)
        label=None
        definition=None
        #skip shape class
        if str(concept)==str(from_graph_superclass):
            g.add((g_superclass,imported_from,from_graph_superclass))
            continue
        else:
            i+=1
            for s,p, o in from_graph.triples((concept,None,None)):
                #print(s,p,o)
                if p==RDFS.label:
                    label=str(o)
                if p==IOFAV.naturalLanguageDefinition:
                    definition=o
            if label:
                short_iri=upper_camel_case(strip_special_chars(label))
                iri=URIRef(PMDCO+short_iri)
                g.add((iri,RDF.type,OWL.Class))
                g.add((iri,imported_from,concept))
                g.add((iri,RDFS.label,Literal(label,lang='en')))
                if definition:
                    g.add((iri,SKOS.definition,definition))
                #g.add((iri,OBO.IAO_0000117,Literal("PERSON: " + editor )))
    logging.info("added {} entities from entity {} as subclasses to {}".format(i,from_graph_superclass,g_superclass))
    return g

# copys subclass relations from equivalentClasses of Pato
def copy_subclass_relations(g: Graph, to_copy_from: Graph) -> Graph:
    i=0
    for s,p, o in g.triples((None,imported_from,None)):
        if isinstance(o,URIRef):
            subclassof=list(to_copy_from.objects(o,RDFS.subClassOf))
            for item in subclassof:
                pmd_class = g.value(predicate=imported_from, object=item, any=False)
                if pmd_class:
                    #print(s,RDFS.subClassOf,pmd_class)
                    g.add((s,RDFS.subClassOf,pmd_class))
                    i+=1
    logging.info("added {} subclass relations from equivalent entities".format(i))
    return g

# chatclient = AzureOpenAI(
#     api_key=os.environ.get("AOAI_API_KEY"),
#     # https://learn.microsoft.com/en-us/azure/ai-services/openai/reference#rest-api-versioning
#     api_version=os.environ.get("AOAI_API_VERSION"),
#     # https://learn.microsoft.com/en-us/azure/cognitive-services/openai/how-to/create-resource?pivots=web-portal#create-a-resource
#     azure_endpoint= os.environ.get("AOAI_API_BASE",""),
# )

def translate_label_completion(text: str, target_language: str="de", definition: str=""): 
    prompt=f"Translate the following label into {target_language}: {text}, stick to the number of words and sequence of word classes if possible.\n"
    if definition:
        prompt+=f"Use the following definition as help: {definition}\n"
    response = chatclient.completions.create( 
    model="TEXTDAVINCI3",
    prompt=prompt,
    max_tokens=60, 
    n=1, 
    stop=None, 
    temperature=0.7, ) 
    return strip_special_chars(response.choices[0].text.strip())

def translate_labels_gpt(g: Graph, language: str='de'):
    res=dict()
    labels_definitions=g.query(all_labels_definitions)    
    for thing, label, definition in labels_definitions:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
        res[thing]["definition"]=definition
    i=0
    for thing, fields in res.items():
        if not all(lang in fields.keys() for lang in ("en","de")):
            if fields.get('en',None):
                definition=fields.get('definition','')
                label_de=Literal(translate_label_completion(fields['en'],target_language=language,definition=definition),lang=language)
                logging.info('adding german label {} for entity {}'.format(label_de, thing))
                g.add((thing,RDFS.label,label_de))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("translated {} labels to [{}]".format(i,language))
    return g

def translate_labels_google(g: Graph, language: str='de'):
    translator=GoogleTranslator(source='auto', target=language)
    res=dict()
    labels=g.query(all_labels)    
    for thing, label in labels:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
    i=0
    for thing, labels in res.items():
        if not all(lang in labels.keys() for lang in ("en","de")):
            #entitys with only one label
            #print(thing,labels)
            #translate and add triple
            if labels.get('en',None):
                label_de=Literal(translator.translate(labels['en']),lang=language)
                logging.info('adding german label {} for entity {}'.format(label_de, thing))
                g.add((thing,RDFS.label,label_de))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("translated {} labels to [{}]".format(i,language))
    return g

def entitle_all_labels(g: Graph):
    res=dict()
    labels=g.query(all_labels)    
    for thing, label in labels:
        if thing not in res.keys():
            res[thing]={}
        res[thing][label.language]=label
    i=0

    for thing, labels in res.items():
        for lang, label in labels.items():
            entitled_label=str(label).title()
            if not str(label)==entitled_label:
                logging.debug('replacing label [{}] with [{}] on {}'.format(str(label), entitled_label, thing))
                #remove old label
                g.remove((thing,RDFS.label,label))
                #add capitalized one
                g.add((thing,RDFS.label,Literal(entitled_label,lang=getattr(label,'language',""))))
                #add curation status - requires discussion
                g.add((thing,OBO.IAO_0000114,OBO.IAO_0000428))
                i+=1
    logging.info("entiteled {} labels".format(i))
    return g


def copy_label_definitions_from_external_terms(source: Graph, target: Graph):
    all_entities=list(source.subjects(unique=True))
    all_entities.extend(source.predicates(unique=True))
    subjects_with_labels={thing: label for thing, label in source.query(all_labels)}.keys()
    subjects_without_labels=[subject for subject in all_entities if subject not in subjects_with_labels and isinstance(subject,URIRef)]
    logger.info("found the following subjects without rdfs:label: {}".format(subjects_without_labels))
    logger.info("graph has {} entities without rdfs:label".format(len(subjects_without_labels)))
    target_subjects_with_labels={thing: label for thing, label in target.query(all_labels)}.keys()
    found_in_target=[subject for subject in subjects_without_labels if subject in target_subjects_with_labels]
    logger.debug("found the following subjects in target:\n{}".format(found_in_target))
    i=0
    for subject in found_in_target:
        for label in target.objects(subject,RDFS.label):
            source.add((subject,RDFS.label,label))
            i+=1
    logger.info("added {} labels for {} subjects found in target".format(i,len(found_in_target)))
    return source

from rdflib import Graph, URIRef, RDF, OWL
import re

def update_class_iris(graph, base_iri, start_index):
    """
    Update class IRIs in an RDFLib graph to follow a specific pattern.

    Parameters:
    - graph: rdflib.Graph
    - base_iri: str, base namespace (e.g., 'https://w3id.org/pmd/co/')
    - start_index: int, starting index for new IRIs (e.g., 40000)
    
    Returns:
    - A dictionary mapping old IRIs to new IRIs.
    """
    pattern = re.compile(re.escape(base_iri) + r'PMD_\d{7}$')
    existing_iris = set(str(s) for s in graph.subjects(RDF.type, OWL.Class) if str(s).startswith(base_iri))
    
    used_numbers = {
        int(re.search(r'(\d{7})$', iri).group(1))
        for iri in existing_iris
        if pattern.match(iri)
    }

    next_index = start_index
    iri_map = {}

    for s in list(graph.subjects(RDF.type, OWL.Class)):
        if isinstance(s, URIRef) and str(s).startswith(base_iri) and not pattern.match(str(s)):
            # Generate next available IRI
            while next_index in used_numbers:
                next_index += 1

            new_iri = URIRef(f"{base_iri}PMD_{next_index:07d}")
            used_numbers.add(next_index)
            iri_map[s] = new_iri
            next_index += 1

    # Replace old IRIs in the graph
    for old_iri, new_iri in iri_map.items():
        for p, o in list(graph.predicate_objects(old_iri)):
            graph.add((new_iri, p, o))
            graph.remove((old_iri, p, o))
        for s, p in list(graph.subject_predicates(old_iri)):
            graph.add((s, p, new_iri))
            graph.remove((s, p, old_iri))
    print(iri_map)
    return graph

print("working on file {}".format(this_ontology_path))
# Out:
# working on file c:\Users\hanke\projects\core-ontology\src\ontology\components\scripts\..\pmdco-logistics.owl

# %%
iof_graph=Graph().parse("https://raw.githubusercontent.com/iofoundry/ontology/refs/heads/master/core/Core.rdf")
iof_graph.parse(iof_supplychain_url)
#iof_graph.serialize(destination="test.ttl")
iao=Graph().parse(iao_url)

# %%
output_filename=filename.replace('.owl','_curated.owl')
#this_ontology_url=path2url(filename)

print(this_ontology_path)
onto=Graph()
onto=parse_graph(this_ontology_path,graph=onto)
onto=add_ontology_header(onto)
# adding rdfs:label for increased readability in editor
#onto=copy_label_definitions_from_external_terms(onto,iao)
default_filter=['increased', 'decreased', 'normal']
map=[
    (PMDCO.PMD_0000017,IOFCORE.Identifier,default_filter),
    (PMDCO.PMD_0040000,IOFCORE.Agreement,default_filter),
    (PMDCO.PMD_0000003,IOFCORE.PlanSpecification,default_filter),
    (OBO.BFO_0000029,OBO.BFO_0000029,default_filter),
    (OBO.BFO_0000028,OBO.BFO_0000028,default_filter),
    (OBO.BFO_0000040,OBO.BFO_0000040,['agent',]),
    (PMDCO.PMD_0040001,IOFCORE.Agent,default_filter),
    (PMDCO.PMD_0040002,IOFSUPPLY.PieceofTransportEquipment,default_filter),
    (OBO.BFO_0000027,IOFCORE.GroupOfAgents,['group of']),
    (PMDCO.PMD_0000879,IOFCORE.Organisation,default_filter),
    (OBO.BFO_0000027,IOFCORE.EngineeredSystem,default_filter),
    (OBO.BFO_0000034,OBO.BFO_0000034,default_filter),
    (OBO.BFO_0000023,OBO.BFO_0000023,default_filter),
    (OBO.BFO_0000003,IOFCORE.Event,default_filter),
    (OBO.BFO_0000015,IOFCORE.PlannedProcess,default_filter),
    
    #(OBO.BFO_0000023,OBO.BFO_0000023,[]),
    #(OBO.BFO_0000034,OBO.BFO_0000034,[]),
    #(OBO.BFO_0000015,OBO.BFO_0000015,[]),
    
    #(PMDCO.PMD_0040001,IOFCORE.Agent,default_filter),    
    #(PMDCO.PMD_0000017,IOFCORE.Identifier,default_filter),IOFSUPPLY.GobalLocationNumber
    # (onto.value(predicate=RDFS.label,object=Literal("Shape", lang="en")),OBO.PATO_0000052,default_filter),
    # (onto.value(predicate=RDFS.label,object=Literal("Size", lang="en")),OBO.PATO_0000117,["uniform", 'increased', 'decreased', 'normal','irregular']),
    # (onto.value(predicate=RDFS.label,object=Literal("Structure", lang="en")),OBO.PATO_0000141,['accumulation','acinar','apoptotic','autogenous', 'fibrinoid', 'neoplastic','with','attachment','complete','water','increased', 'decreased', 'normal', 'maximal', 'from', 'to']),
    # (onto.value(predicate=RDFS.label,object=Literal("Texture", lang="en")),OBO.PATO_0000150,default_filter),
    # (onto.value(predicate=RDFS.label,object=Literal("Spatial Pattern", lang="en")),OBO.PATO_0000060,default_filter),
    # #(onto.value(predicate=RDFS.label,object=Literal("Molecular Quality", lang="en")),OBO.PATO_0002182,["affinity", "concentration", "osmolality"," osmolarity"]),
    # (onto.value(predicate=RDFS.label,object=Literal("Odor", lang="en")),OBO.PATO_0000058,default_filter),
    # (onto.value(predicate=RDFS.label,object=Literal("Organismal Quality", lang="en")),OBO.PATO_0001995,["resistance", "response", "sensitivity", 'increased', 'decreased', 'normal']),
    # (onto.value(predicate=RDFS.label,object=Literal("Cellular Quality", lang="en")),OBO.PATO_0001396,default_filter),
    ]
for target, source, filters in map:
    if target and source:
        onto=import_entities(g=onto,g_superclass=target,from_graph=iof_graph,from_graph_superclass=source,filters=filters)


onto=copy_subclass_relations(onto,iof_graph)
#onto=translate_labels_google(onto,language='de')
# onto=translate_labels_gpt(onto,language='de')

# onto=entitle_all_labels(onto)

onto=update_class_iris(onto, base_iri=PMDCO, start_index=40000)
print(f"serialize to {output_filename} in format {output_format}")
onto.serialize(output_filename,format='xml')
print(f"reformated {output_filename} to manchester syntax {output_format}")

pyhornedowl.open_ontology(output_filename,serialization='owl').save_to_file(output_filename, serialization='ofn')
# Out:
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 6 entities from entity https://spec.industrialontologies.org/ontology/core/Core/Identifier as subclasses to https://w3id.org/pmd/co/PMD_0000017
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 6 entities from entity https://spec.industrialontologies.org/ontology/core/Core/Agreement as subclasses to https://w3id.org/pmd/co/PMD_0040000
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 12 entities from entity https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification as subclasses to https://w3id.org/pmd/co/PMD_0000003
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 2 entities from entity http://purl.obolibrary.org/obo/BFO_0000029 as subclasses to http://purl.obolibrary.org/obo/BFO_0000029
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 3 entities from entity http://purl.obolibrary.org/obo/BFO_0000028 as subclasses to http://purl.obolibrary.org/obo/BFO_0000028
# INFO:root:filtered out 14 entities because there labels contain one of the words ['agent']
# INFO:root:added 8 entities from entity http://purl.obolibrary.org/obo/BFO_0000040 as subclasses to http://purl.obolibrary.org/obo/BFO_0000040
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 13 entities from entity https://spec.industrialontologies.org/ontology/core/Core/Agent as subclasses to https://w3id.org/pmd/co/PMD_0040001
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 3 entities from entity https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment as subclasses to https://w3id.org/pmd/co/PMD_0040002
# INFO:root:filtered out 7 entities because there labels contain one of the words ['group of']
# INFO:root:added 0 entities from entity https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents as subclasses to http://purl.obolibrary.org/obo/BFO_0000027
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity https://spec.industrialontologies.org/ontology/core/Core/Organisation as subclasses to https://w3id.org/pmd/co/PMD_0000879
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 6 entities from entity https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem as subclasses to http://purl.obolibrary.org/obo/BFO_0000027
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 5 entities from entity http://purl.obolibrary.org/obo/BFO_0000034 as subclasses to http://purl.obolibrary.org/obo/BFO_0000034
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 30 entities from entity http://purl.obolibrary.org/obo/BFO_0000023 as subclasses to http://purl.obolibrary.org/obo/BFO_0000023
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 0 entities from entity https://spec.industrialontologies.org/ontology/core/Core/Event as subclasses to http://purl.obolibrary.org/obo/BFO_0000003
# c:\Users\hanke\projects\core-ontology\src\ontology\components\scripts\..\pmdco-logistics.owl
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/Identifier as subclasses of https://w3id.org/pmd/co/PMD_0000017
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Identifier: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Identifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizationIdentifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PhysicalLocationIdentifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GlobalLocationNumber'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotNumber'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PartNumber'), rdflib.term.BNode('N9c4bcd651d96460e816c991559cf333b')]
# Found 7 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Identifier
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Identifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizationIdentifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PhysicalLocationIdentifier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GlobalLocationNumber'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotNumber'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PartNumber'), rdflib.term.BNode('N9c4bcd651d96460e816c991559cf333b')]
# https://spec.industrialontologies.org/ontology/core/Core/Identifier
# https://spec.industrialontologies.org/ontology/core/Core/OrganizationIdentifier
# https://spec.industrialontologies.org/ontology/core/Core/PhysicalLocationIdentifier
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GlobalLocationNumber
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotNumber
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PartNumber
# N9c4bcd651d96460e816c991559cf333b
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/Agreement as subclasses of https://w3id.org/pmd/co/PMD_0040000
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agreement: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agreement'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceAgreement'), rdflib.term.BNode('Nfa2b7a2d8594475291d6823e5fe80b66'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/BillOfLading'), rdflib.term.BNode('N7efc2d8570bf4e688a9890b71c7a8990'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PurchaseOrder'), rdflib.term.BNode('N78cf86fe64c144eebb8e091900c7d192')]
# Found 7 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agreement
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agreement'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceAgreement'), rdflib.term.BNode('Nfa2b7a2d8594475291d6823e5fe80b66'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/BillOfLading'), rdflib.term.BNode('N7efc2d8570bf4e688a9890b71c7a8990'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PurchaseOrder'), rdflib.term.BNode('N78cf86fe64c144eebb8e091900c7d192')]
# https://spec.industrialontologies.org/ontology/core/Core/Agreement
# https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceAgreement
# Nfa2b7a2d8594475291d6823e5fe80b66
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/BillOfLading
# N7efc2d8570bf4e688a9890b71c7a8990
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PurchaseOrder
# N78cf86fe64c144eebb8e091900c7d192
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification as subclasses of https://w3id.org/pmd/co/PMD_0000003
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceSpecification'), rdflib.term.BNode('Nbf817d2d80ca488f9d279bc70550529e'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EncodedAlgorithm'), rdflib.term.BNode('N3e60e964a7af43068e8be6d6c3e19e4e'), rdflib.term.BNode('N72fcd289834645e4845cd756525ff533'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PackagingPlanSpecification'), rdflib.term.BNode('Nb89887b002d94303b7ae49fe522df698'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentPlanSpecification'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainPlanSpecification'), rdflib.term.BNode('N365d9f3e4455420b99c39a15613dfe3a'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WarehousingPlanSpecification'), rdflib.term.BNode('N21442fe43eb94469a632e3b91e696a63')]
# Found 13 subclasses of https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceSpecification'), rdflib.term.BNode('Nbf817d2d80ca488f9d279bc70550529e'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EncodedAlgorithm'), rdflib.term.BNode('N3e60e964a7af43068e8be6d6c3e19e4e'), rdflib.term.BNode('N72fcd289834645e4845cd756525ff533'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PackagingPlanSpecification'), rdflib.term.BNode('Nb89887b002d94303b7ae49fe522df698'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentPlanSpecification'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainPlanSpecification'), rdflib.term.BNode('N365d9f3e4455420b99c39a15613dfe3a'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WarehousingPlanSpecification'), rdflib.term.BNode('N21442fe43eb94469a632e3b91e696a63')]
# https://spec.industrialontologies.org/ontology/core/Core/PlanSpecification
# https://spec.industrialontologies.org/ontology/core/Core/CommercialServiceSpecification
# Nbf817d2d80ca488f9d279bc70550529e
# https://spec.industrialontologies.org/ontology/core/Core/EncodedAlgorithm
# N3e60e964a7af43068e8be6d6c3e19e4e
# N72fcd289834645e4845cd756525ff533
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PackagingPlanSpecification
# Nb89887b002d94303b7ae49fe522df698
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentPlanSpecification
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainPlanSpecification
# N365d9f3e4455420b99c39a15613dfe3a
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WarehousingPlanSpecification
# N21442fe43eb94469a632e3b91e696a63
# importing entities from http://purl.obolibrary.org/obo/BFO_0000029 as subclasses of http://purl.obolibrary.org/obo/BFO_0000029
# Found following subclasses of http://purl.obolibrary.org/obo/BFO_0000029: [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000029'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialSite'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialLocation')]
# Found 3 subclasses of http://purl.obolibrary.org/obo/BFO_0000029
# [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000029'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialSite'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialLocation')]
# http://purl.obolibrary.org/obo/BFO_0000029
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialSite
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GeospatialLocation
# importing entities from http://purl.obolibrary.org/obo/BFO_0000028 as subclasses of http://purl.obolibrary.org/obo/BFO_0000028
# Found following subclasses of http://purl.obolibrary.org/obo/BFO_0000028: [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000028'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Airway'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Seaway'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShippingRoute')]
# Found 4 subclasses of http://purl.obolibrary.org/obo/BFO_0000028
# [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000028'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Airway'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Seaway'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShippingRoute')]
# http://purl.obolibrary.org/obo/BFO_0000028
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Airway
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Seaway
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShippingRoute
# importing entities from http://purl.obolibrary.org/obo/BFO_0000040 as subclasses of http://purl.obolibrary.org/obo/BFO_0000040
# Found following subclasses of http://purl.obolibrary.org/obo/BFO_0000040: [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000040'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Buyer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Customer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Manufacturer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Supplier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialComponent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialProduct'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialResource'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/RawMaterial'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Cargo'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventory'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnit')]
# Found 23 subclasses of http://purl.obolibrary.org/obo/BFO_0000040
# [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000040'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Buyer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Customer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Manufacturer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Supplier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialComponent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialProduct'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialResource'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/RawMaterial'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Cargo'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventory'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnit')]
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agent: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Buyer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Customer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Manufacturer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Supplier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler')]
# Found 14 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agent
# Found following subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent')]
# Found 1 subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent
# http://purl.obolibrary.org/obo/BFO_0000040
# https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItem
# https://spec.industrialontologies.org/ontology/core/Core/MaterialComponent
# https://spec.industrialontologies.org/ontology/core/Core/MaterialProduct
# https://spec.industrialontologies.org/ontology/core/Core/MaterialResource
# https://spec.industrialontologies.org/ontology/core/Core/RawMaterial
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Cargo
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventory
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnit
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/Agent as subclasses of https://w3id.org/pmd/co/PMD_0040001
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agent: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Buyer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Customer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Manufacturer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Supplier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler')]
# Found 14 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Agent
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Agent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Buyer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Customer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Manufacturer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Supplier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler')]
# https://spec.industrialontologies.org/ontology/core/Core/Agent
# https://spec.industrialontologies.org/ontology/core/Core/Buyer
# https://spec.industrialontologies.org/ontology/core/Core/Customer
# https://spec.industrialontologies.org/ontology/core/Core/Manufacturer
# https://spec.industrialontologies.org/ontology/core/Core/Supplier
# https://spec.industrialontologies.org/ontology/core/Core/ServiceProvider
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Carrier
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Consignee
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Distributor
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwarder
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Retailer
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Shipper
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainAgent
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wholesaler
# importing entities from https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment as subclasses of https://w3id.org/pmd/co/PMD_0040002
# Found following subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Container'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Trailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wagon')]
# Found 4 subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Container'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Trailer'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wagon')]
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/PieceofTransportEquipment
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Container
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Trailer
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Wagon
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents as subclasses of http://purl.obolibrary.org/obo/BFO_0000027
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IntegratedCarrierBusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Industry')]
# Found 7 subclasses of https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IntegratedCarrierBusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Industry')]
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IntegratedCarrierBusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Industry')]
# Found 7 subclasses of https://spec.industrialontologies.org/ontology/core/Core/GroupOfAgents
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IntegratedCarrierBusinessOrganization'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers')]
# Found 5 subclasses of https://spec.industrialontologies.org/ontology/core/Core/OrganizedGroupOfAgents
# Found following subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers')]
# Found 1 subclasses of https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/GroupOfSuppliers
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/Organisation as subclasses of https://w3id.org/pmd/co/PMD_0000879
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Organisation: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organisation')]
# Found 1 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Organisation
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Organisation')]
# https://spec.industrialontologies.org/ontology/core/Core/Organisation
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem as subclasses of http://purl.obolibrary.org/obo/BFO_0000027
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Facility'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageFacility'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributionCenter'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainSystem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ManufacturingSupplyChain'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceSupplyChain')]
# Found 7 subclasses of https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Facility'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageFacility'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributionCenter'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainSystem'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ManufacturingSupplyChain'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceSupplyChain')]
# https://spec.industrialontologies.org/ontology/core/Core/EngineeredSystem
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/Facility
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageFacility
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributionCenter
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainSystem
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ManufacturingSupplyChain
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceSupplyChain
# importing entities from http://purl.obolibrary.org/obo/BFO_0000034 as subclasses of http://purl.obolibrary.org/obo/BFO_0000034
# Found following subclasses of http://purl.obolibrary.org/obo/BFO_0000034: [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000034'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessFunction'), rdflib.term.BNode('N6481b550466b4c4cb1c8e11ad977f194'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwardingBusinessFunction'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/DesignedFunction'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArtifactFunction')]
# Found 6 subclasses of http://purl.obolibrary.org/obo/BFO_0000034
# [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000034'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessFunction'), rdflib.term.BNode('N6481b550466b4c4cb1c8e11ad977f194'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwardingBusinessFunction'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/DesignedFunction'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArtifactFunction')]
# http://purl.obolibrary.org/obo/BFO_0000034
# https://spec.industrialontologies.org/ontology/core/Core/BusinessFunction
# N6481b550466b4c4cb1c8e11ad977f194
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/FreightForwardingBusinessFunction
# https://spec.industrialontologies.org/ontology/core/Core/DesignedFunction
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArtifactFunction
# importing entities from http://purl.obolibrary.org/obo/BFO_0000023 as subclasses of http://purl.obolibrary.org/obo/BFO_0000023
# Found following subclasses of http://purl.obolibrary.org/obo/BFO_0000023: [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000023'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/AgentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BuyerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CustomerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceConsumerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ManufacturerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SupplierRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/service/ServiceOntology/ManufacturingServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigneeRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsignorRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributorRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/RetailerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WholesalerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EquipmentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItemRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialComponentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialProductRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialResourceRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventoryRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/RawMaterialRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/CargoRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipFromLocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipToLocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnitRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LoadRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticUnitRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentRole')]
# Found 31 subclasses of http://purl.obolibrary.org/obo/BFO_0000023
# [rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000023'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/AgentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BuyerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CustomerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceConsumerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ManufacturerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SupplierRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/service/ServiceOntology/ManufacturingServiceProviderRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigneeRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsignorRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributorRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/RetailerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WholesalerRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/EquipmentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItemRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialComponentRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialProductRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialResourceRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventoryRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/RawMaterialRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/CargoRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipFromLocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipToLocationRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnitRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LoadRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticUnitRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotRole'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentRole')]
# http://purl.obolibrary.org/obo/BFO_0000023
# https://spec.industrialontologies.org/ontology/core/Core/AgentRole
# https://spec.industrialontologies.org/ontology/core/Core/BuyerRole
# https://spec.industrialontologies.org/ontology/core/Core/CustomerRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ServiceConsumerRole
# https://spec.industrialontologies.org/ontology/core/Core/ManufacturerRole
# https://spec.industrialontologies.org/ontology/core/Core/SupplierRole
# https://spec.industrialontologies.org/ontology/core/Core/ServiceProviderRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsServiceProviderRole
# https://spec.industrialontologies.org/ontology/supplychain/service/ServiceOntology/ManufacturingServiceProviderRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigneeRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsignorRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DistributorRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/RetailerRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/WholesalerRole
# https://spec.industrialontologies.org/ontology/core/Core/EquipmentRole
# https://spec.industrialontologies.org/ontology/core/Core/MaintainableMaterialItemRole
# https://spec.industrialontologies.org/ontology/core/Core/MaterialComponentRole
# https://spec.industrialontologies.org/ontology/core/Core/MaterialProductRole
# https://spec.industrialontologies.org/ontology/core/Core/MaterialResourceRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/IndustrialInventoryRole
# https://spec.industrialontologies.org/ontology/core/Core/RawMaterialRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/CargoRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LocationRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipFromLocationRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipToLocationRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TraceableResourceUnitRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LoadRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticUnitRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LotRole
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ShipmentRole
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/Event as subclasses of http://purl.obolibrary.org/obo/BFO_0000003
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/Event: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Event')]
# Found 1 subclasses of https://spec.industrialontologies.org/ontology/core/Core/Event
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/Event')]
# https://spec.industrialontologies.org/ontology/core/Core/Event
# importing entities from https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess as subclasses of http://purl.obolibrary.org/obo/BFO_0000015
# Found following subclasses of https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess: [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BuyingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialService'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsService'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ProcuringBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ProductProductionProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SellingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SupplyingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigningProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/InventoryManagementProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ReceivingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ComputingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ManufacturingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/AssemblyProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialLocationChangeProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArrivalProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DepartureProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TransportProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TravelProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MeasurementProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/AppraisalProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageProcess')]
# Found 25 subclasses of https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess
# [rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/BuyingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/CommercialService'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsService'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ProcuringBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ProductProductionProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SellingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/SupplyingBusinessProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigningProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/InventoryManagementProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ReceivingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ComputingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/ManufacturingProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/AssemblyProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MaterialLocationChangeProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArrivalProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DepartureProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TransportProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TravelProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/core/Core/MeasurementProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/AppraisalProcess'), rdflib.term.URIRef('https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageProcess')]
# INFO:root:filtered out 0 entities because there labels contain one of the words ['increased', 'decreased', 'normal']
# INFO:root:added 24 entities from entity https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess as subclasses to http://purl.obolibrary.org/obo/BFO_0000015
# INFO:root:added 107 subclass relations from equivalent entities
# https://spec.industrialontologies.org/ontology/core/Core/PlannedProcess
# https://spec.industrialontologies.org/ontology/core/Core/BusinessProcess
# https://spec.industrialontologies.org/ontology/core/Core/BuyingBusinessProcess
# https://spec.industrialontologies.org/ontology/core/Core/CommercialService
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsService
# https://spec.industrialontologies.org/ontology/core/Core/ProcuringBusinessProcess
# https://spec.industrialontologies.org/ontology/core/Core/ProductProductionProcess
# https://spec.industrialontologies.org/ontology/core/Core/SellingBusinessProcess
# https://spec.industrialontologies.org/ontology/core/Core/SupplyingBusinessProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ConsigningProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/InventoryManagementProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/LogisticsProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ReceivingProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/SupplyChainProcess
# https://spec.industrialontologies.org/ontology/core/Core/ComputingProcess
# https://spec.industrialontologies.org/ontology/core/Core/ManufacturingProcess
# https://spec.industrialontologies.org/ontology/core/Core/AssemblyProcess
# https://spec.industrialontologies.org/ontology/core/Core/MaterialLocationChangeProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/ArrivalProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/DepartureProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TransportProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/TravelProcess
# https://spec.industrialontologies.org/ontology/core/Core/MeasurementProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/AppraisalProcess
# https://spec.industrialontologies.org/ontology/supplychain/SupplyChain/StorageProcess
# {rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000014'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040003'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000598'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040004'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000599'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040005'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000793'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040006'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000814'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040007'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000815'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040008'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000830'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040009'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000831'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040010'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000873'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040011'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000879'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040012'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000881'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040013'), rdflib.term.URIRef('https://w3id.org/pmd/co/logistics/PMD_0000909'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040014'), rdflib.term.URIRef('https://w3id.org/pmd/co/OrganizationIdentifier'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040015'), rdflib.term.URIRef('https://w3id.org/pmd/co/PhysicalLocationIdentifier'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040016'), rdflib.term.URIRef('https://w3id.org/pmd/co/GlobalLocationNumber'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040017'), rdflib.term.URIRef('https://w3id.org/pmd/co/LotNumber'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040018'), rdflib.term.URIRef('https://w3id.org/pmd/co/PartNumber'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040019'), rdflib.term.URIRef('https://w3id.org/pmd/co/CommercialServiceAgreement'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040020'), rdflib.term.URIRef('https://w3id.org/pmd/co/BillOfLading'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040021'), rdflib.term.URIRef('https://w3id.org/pmd/co/PurchaseOrder'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040022'), rdflib.term.URIRef('https://w3id.org/pmd/co/CommercialServiceSpecification'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040023'), rdflib.term.URIRef('https://w3id.org/pmd/co/EncodedAlgorithm'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040024'), rdflib.term.URIRef('https://w3id.org/pmd/co/PackagingPlanSpecification'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040025'), rdflib.term.URIRef('https://w3id.org/pmd/co/ShipmentPlanSpecification'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040026'), rdflib.term.URIRef('https://w3id.org/pmd/co/SupplyChainPlanSpecification'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040027'), rdflib.term.URIRef('https://w3id.org/pmd/co/WarehousingPlanSpecification'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040028'), rdflib.term.URIRef('https://w3id.org/pmd/co/GeospatialSite'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040029'), rdflib.term.URIRef('https://w3id.org/pmd/co/GeospatialLocation'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040030'), rdflib.term.URIRef('https://w3id.org/pmd/co/Airway'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040031'), rdflib.term.URIRef('https://w3id.org/pmd/co/Seaway'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040032'), rdflib.term.URIRef('https://w3id.org/pmd/co/ShippingRoute'): rdflib.term.URIRef('https://w3id.org/pmd/co/PMD_0040033'), rdflib.term.URIRef('https://w3id.org/pmd/co/MaintainableMaterialItem'): rdflib.ter ...
# serialize to ../pmdco-logistics_curated.owl in format application/rdf+xml
# reformated ../pmdco-logistics_curated.owl to manchester syntax application/rdf+xml
